# %% [markdown]
# # **Trabajo de Fin de Máster**

# %%
# %cd /Users/andreea/Desktop/TFM/git/qubart/eval
# %load_ext autoreload
# %autoreload 2
from utils import *
from constants import *
from rouge import Rouge
import re
from tqdm.notebook import tqdm, trange
import time    # to be used in loop iterations
import string
# Out:
# /Users/andreea/Desktop/TFM/git/qubart/eval
# /Users/andreea/miniconda3/envs/tfm/lib/python3.9/site-packages/streamlit/elements/arrow.py:15: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#   from collections import Iterable

# %%
corpus = load_corpus(f"/Users/andreea/Desktop/TFM/git/qubart/corpus/{CORPUS_GOT_REVIEWS}")['train']
# Out:
# 2021-09-26 14:06:59.082 WARNING datasets.builder: Using custom data configuration default-4df86dcbda049c0c
# 2021-09-26 14:06:59.090 WARNING datasets.builder: Reusing dataset csv (/Users/andreea/.cache/huggingface/datasets/csv/default-4df86dcbda049c0c/0.0.0/9144e0a4e8435090117cea53e6c7537173ef2304525df4a077c435d8ee7828ff)

# %%
rouge = Rouge()
rouge_measures = ["rouge-1", "rouge-2", "rouge-l"]
columns = ['Reference data length', 'Filtered data length', 'Summary length', 'Precision', 'Recall', 'F-Score', 'Filtered']


def get_length_text(text):
    words = [''.join(x for x in par if x not in string.punctuation) for par in text.split()]
    words = list(filter(lambda a: a != '', words))
    lenght_text = len(words)
    return lenght_text
    
def get_rouge_columns(df):
    '''
    '''
    df_aux = df
    df_r1 = df_aux.iloc[::3, :]
    df = df_aux.drop(df_aux.iloc[::3, :].index)
    df_r2 = df.iloc[::2, :]
    df_rl = df.drop(df.iloc[::2, :].index)
    return df_r1, df_r2, df_rl

# Show top n keywords for each topic
def get_word_topic(vectorizer, lda_model, n_words=1):
    keywords = np.array(vectorizer.get_feature_names())
    topic_keywords = []
    for topic_weights in lda_model.components_:
        top_keyword_locs = (-topic_weights).argsort()[:n_words]
        topic_keywords.append(keywords.take(top_keyword_locs))
    return topic_keywords

def get_filter_by(input_data, num_topics):
    lda_model, vectorizer, data_lda = get_LDA(input_data, num_topics)
    topic_keywords = get_word_topic(vectorizer=vectorizer, lda_model=lda_model, n_words=1)
    return topic_keywords[np.argmax(data_lda)][0]    


def create_table_rouge(hyps, refs, rouge_measures, index, columns, ref_length, summary_length, filtered_length, filtered):
    scores = rouge.get_scores(hyps=hyps, refs=refs)
    table = get_df_rouge_scores(scores=[scores[0]],
                                rouge_measures=rouge_measures,
                                index=index,    
                                columns=columns,
                                ref_length = ref_length,
                                summary_length = summary_length,
                                filtered_length = filtered_length,
                                filtered=filtered)
    return table
    
def get_rouge_scores(sentences, filtered_data, summary, target_summary, is_filtered, episode, lead_n = 3):
    '''
    '''
    index = [f"Entry {episode} (R1)", f"Episode {episode} (R2)", f"Episode {episode} (RL)"]
    
    filtered_length = get_length_text(filtered_data) if filtered_data != "" else 0
    
    table_orig_text = create_table_rouge(hyps=summary, 
                                    refs=''.join(sentences),
                                    rouge_measures=rouge_measures,
                                    index=index,
                                    columns=columns,
                                    ref_length = get_length_text(''.join(sentences)),
                                    summary_length = get_length_text(summary),
                                    filtered_length = filtered_length,
                                    filtered=is_filtered)

    if target_summary != "":
        table_target = create_table_rouge(hyps=summary, 
                                    refs=''.join(target_summary),
                                    rouge_measures=rouge_measures,
                                    index=index,
                                    columns=columns,
                                    ref_length = get_length_text(''.join(sentences)),
                                    summary_length = get_length_text(''.join(target_summary)),
                                    filtered_length = filtered_length,
                                    filtered=is_filtered)
    else:
        table_target = pd.DataFrame()
    
    leadn_ref_text = summary if target_summary == "" else ''.join(target_summary)

    table_leadn = create_table_rouge(hyps=''.join(sentences[:lead_n]),
                                     refs=leadn_ref_text,
                                     rouge_measures=rouge_measures,
                                     index=index,
                                     columns=columns,
                                     ref_length = get_length_text(leadn_ref_text),
                                     summary_length = get_length_text(''.join(sentences[:lead_n])),
                                     filtered_length = filtered_length,
                                     filtered=is_filtered)
    
    if filtered_data != "":
        table_filtered = create_table_rouge(hyps=summary,
                                            refs=filtered_data,
                                            rouge_measures=rouge_measures,
                                            index=index,
                                            columns=columns,
                                            ref_length = get_length_text(''.join(sentences)),
                                            summary_length = get_length_text(summary),
                                            filtered_length = filtered_length,
                                            filtered=is_filtered)
        
        return table_orig_text, table_target, table_leadn, table_filtered
    
    return table_orig_text, table_target, table_leadn

def calculate_rouge_qubart(data, len_data, model="sshleifer/distilbart-cnn-12-6", filter_by=None, num_topics=10, similarity_threshold=0.3, use_columns=False):
    df_orig = pd.DataFrame(columns=columns)
    df_filtered = pd.DataFrame(columns=columns)
    df_leadn = pd.DataFrame(columns=columns)
    df_target = pd.DataFrame(columns=columns)

    for entry in trange(len_data):
        filtered = 0
        
        if use_columns:
            text = data[entry]['text']
            text = "".join(text)
        else:
            text = data[entry]
            
        sentences = re.split(REGEX_EOS, text)
        sentences = [sentence.strip() for sentence in sentences]
        
        target_summary = ""
        
        if use_columns:
            target_summary = data[entry]['summary']
        
        embedded_sentences = get_sentence_embeddings(sentences)
        
        if not filter_by:
            entry_filter_by = get_filter_by(text, num_topics)
        else:
            entry_filter_by = filter_by
            
        similar_sentences = get_similar_sentences(get_sentence_embeddings(entry_filter_by), embedded_sentences,
                                                 similarity_threshold=similarity_threshold)
        filtered_text = ""
        for idx in similar_sentences:
            filtered_text = filtered_text + sentences[idx]
            
        if filtered_text == "":
            summary = get_summary(text, model)
            table_orig, table_target, table_leadn = get_rouge_scores(sentences=sentences,
                                                                  filtered_data=filtered_text,
                                                                  target_summary = target_summary,
                                                                  summary=summary[0],
                                                                  is_filtered=filtered,
                                                                  episode=entry)
        else:
            filtered = 1
            summary = get_summary(filtered_text, model)
            table_orig, table_target, table_leadn, table_filtered = get_rouge_scores(sentences=sentences,
                                                                                  filtered_data=filtered_text,
                                                                                  target_summary = target_summary,
                                                                                  summary=summary[0],
                                                                                  is_filtered=filtered,
                                                                                  episode=entry)
            df_filtered = df_filtered.append(table_filtered)
        
        df_orig = df_orig.append(table_orig)
        df_leadn = df_leadn.append(table_leadn)
        if not table_target.empty:
            df_target = df_leadn.append(table_target)
    
    return df_orig, df_target, df_filtered, df_leadn

# %%
import jsonlines

def load_dataset(file, max_num_entries=100):
    with jsonlines.open(file) as f:
        counter = 0
        lines = {}
        for line in f.iter():
            if counter == max_num_entries:
                break
            else:
                lines[counter] = {'text': line['text'],
                                 'summary': line['summary']}
                counter = counter + 1
        return lines

# %%
xsum_lines = load_dataset('datasets/ACL2020_other_datasets/test_xsum.jsonl')
cnndm_lines = load_dataset('datasets/ACL2020_data/test_CNNDM_bert.jsonl')
wikihow_lines = load_dataset('datasets/ACL2020_other_datasets/test_wikihow.jsonl')

# %% [markdown]
# # **Game of Thrones**

# %%
df_orig, df_ref, df_filtered, df_leadn = calculate_rouge_qubart(data=corpus[REV_REVIEW], len_data=len(corpus[REV_REVIEW]), filter_by="Bran", similarity_threshold=0.3)
df_r1, df_r2, df_rl = get_rouge_columns(df_orig)
df_r1_filtered, df_r2_filtered, df_rl_filtered = get_rouge_columns(df_filtered)
df_r1_lead3, df_r2_lead3, df_rl_lead3 = get_rouge_columns(df_leadn)
if not df_ref.empty:
    df_r1_ref, df_r2_ref, df_rl_ref = get_rouge_columns(df_ref)
# Out:
#   0%|          | 0/73 [00:00<?, ?it/s]
# /Users/andreea/miniconda3/envs/tfm/lib/python3.9/site-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  ../aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)

# %% [markdown]
# ## **R1 metric**

# %%
df_r1.mean()
# Out:
# Reference data length    773.808219
# Filtered data length      42.123288
# Summary length            52.876712
# Precision                  0.127238
# Recall                     0.911770
# F-Score                    0.210591
# Filtered                   0.356164
# dtype: float64

# %%
df_r1.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#              Reference data length Filtered data length Summary length  \
# Entry 4 (R1)                    57                    0             41
# Entry 3 (R1)                    63                    0             37
# Entry 0 (R1)                   146                    0             58
# Entry 8 (R1)                   302                    0             71
# Entry 2 (R1)                   195                    0             50
#
#               Precision    Recall   F-Score Filtered
# Entry 4 (R1)   0.740000  0.948718  0.831461        0
# Entry 3 (R1)   0.528302  0.823529  0.643678        0
# Entry 0 (R1)   0.380165  0.938776  0.541176        0
# Entry 8 (R1)   0.276498  0.952381  0.428571        0
# Entry 2 (R1)   0.273381  0.950000  0.424581        0

# %%
df_r1_filtered.mean()
# Out:
# Reference data length    896.307692
# Filtered data length     118.269231
# Summary length            50.384615
# Precision                  0.572589
# Recall                     0.918358
# F-Score                    0.665945
# Filtered                   1.000000
# dtype: float64

# %%
df_r1_filtered.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#               Reference data length Filtered data length Summary length  \
# Entry 59 (R1)                  1181                   40             51
# Entry 29 (R1)                   977                   45             44
# Entry 19 (R1)                   898                   38             45
# Entry 52 (R1)                  1129                   64             62
# Entry 66 (R1)                  1419                   56             45
#
#                Precision    Recall   F-Score Filtered
# Entry 59 (R1)   0.909091  0.909091  0.909091        1
# Entry 29 (R1)   0.871795  0.944444  0.906667        1
# Entry 19 (R1)   0.909091  0.857143  0.882353        1
# Entry 52 (R1)   0.843137  0.895833  0.868687        1
# Entry 66 (R1)   0.770833  0.973684  0.860465        1

# %%
df_r1_lead3.mean()
# Out:
# Reference data length     52.876712
# Filtered data length      42.123288
# Summary length           112.054795
# Precision                  0.456529
# Recall                     0.238365
# F-Score                    0.306507
# Filtered                   0.356164
# dtype: float64

# %%
df_r1_lead3.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#               Reference data length Filtered data length Summary length  \
# Entry 4 (R1)                     41                    0             57
# Entry 8 (R1)                     71                    0             96
# Entry 3 (R1)                     37                    0             63
# Entry 58 (R1)                    52                    0            106
# Entry 55 (R1)                    82                  178            135
#
#                Precision    Recall   F-Score Filtered
# Entry 4 (R1)    0.948718  0.740000  0.831461        0
# Entry 8 (R1)    0.952381  0.714286  0.816327        0
# Entry 3 (R1)    0.823529  0.528302  0.643678        0
# Entry 58 (R1)   0.926829  0.457831  0.612903        0
# Entry 55 (R1)   0.761905  0.500000  0.603774        1

# %%
if not df_ref.empty:
    print(df_r1_ref.mean())

# %% [markdown]
# ## **R2 metric**

# %%
df_r2.mean()
# Out:
# Reference data length    773.808219
# Filtered data length      42.123288
# Summary length            52.876712
# Precision                  0.085473
# Recall                     0.794329
# F-Score                    0.143500
# Filtered                   0.356164
# dtype: float64

# %%
df_r2.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                Reference data length Filtered data length Summary length  \
# Episode 4 (R2)                    57                    0             41
# Episode 3 (R2)                    63                    0             37
# Episode 0 (R2)                   146                    0             58
# Episode 8 (R2)                   302                    0             71
# Episode 2 (R2)                   195                    0             50
#
#                 Precision    Recall   F-Score Filtered
# Episode 4 (R2)   0.607143  0.850000  0.708333        0
# Episode 3 (R2)   0.403226  0.694444  0.510204        0
# Episode 0 (R2)   0.342466  0.877193  0.492611        0
# Episode 8 (R2)   0.218121  0.928571  0.353261        0
# Episode 2 (R2)   0.202073  0.812500  0.323651        0

# %%
df_r2_filtered.mean()
# Out:
# Reference data length    896.307692
# Filtered data length     118.269231
# Summary length            50.384615
# Precision                  0.508384
# Recall                     0.832168
# F-Score                    0.576648
# Filtered                   1.000000
# dtype: float64

# %%
df_r2_filtered.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 29 (R2)                   977                   45             44
# Episode 59 (R2)                  1181                   40             51
# Episode 26 (R2)                   573                   62             46
# Episode 52 (R2)                  1129                   64             62
# Episode 19 (R2)                   898                   38             45
#
#                  Precision    Recall   F-Score Filtered
# Episode 29 (R2)   0.822222  0.860465  0.840909        1
# Episode 59 (R2)   0.894737  0.739130  0.809524        1
# Episode 26 (R2)   0.700000  0.933333  0.800000        1
# Episode 52 (R2)   0.774194  0.800000  0.786885        1
# Episode 19 (R2)   0.837838  0.704545  0.765432        1

# %%
df_r2_lead3.mean()
# Out:
# Reference data length     52.876712
# Filtered data length      42.123288
# Summary length           112.054795
# Precision                  0.279275
# Recall                     0.130826
# F-Score                    0.173545
# Filtered                   0.356164
# dtype: float64

# %%
df_r2_lead3.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 8 (R2)                     71                    0             96
# Episode 4 (R2)                     41                    0             57
# Episode 58 (R2)                    52                    0            106
# Episode 3 (R2)                     37                    0             63
# Episode 55 (R2)                    82                  178            135
#
#                  Precision    Recall   F-Score Filtered
# Episode 8 (R2)    0.928571  0.677083  0.783133        0
# Episode 4 (R2)    0.850000  0.607143  0.708333        0
# Episode 58 (R2)   0.823529  0.400000  0.538462        0
# Episode 3 (R2)    0.694444  0.403226  0.510204        0
# Episode 55 (R2)   0.641975  0.403101  0.495238        1

# %%
if not df_ref.empty:
    print(df_r2_ref.mean())

# %% [markdown]
# ## **RL metric**

# %%
df_rl.mean()
# Out:
# Reference data length    773.808219
# Filtered data length      42.123288
# Summary length            52.876712
# Precision                  0.126351
# Recall                     0.903553
# F-Score                    0.209005
# Filtered                   0.356164
# dtype: float64

# %%
df_rl.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                Reference data length Filtered data length Summary length  \
# Episode 4 (RL)                    57                    0             41
# Episode 3 (RL)                    63                    0             37
# Episode 0 (RL)                   146                    0             58
# Episode 8 (RL)                   302                    0             71
# Episode 2 (RL)                   195                    0             50
#
#                 Precision    Recall   F-Score Filtered
# Episode 4 (RL)   0.740000  0.948718  0.831461        0
# Episode 3 (RL)   0.528302  0.823529  0.643678        0
# Episode 0 (RL)   0.380165  0.938776  0.541176        0
# Episode 8 (RL)   0.276498  0.952381  0.428571        0
# Episode 2 (RL)   0.273381  0.950000  0.424581        0

# %%
df_rl_filtered.mean()
# Out:
# Reference data length    896.307692
# Filtered data length     118.269231
# Summary length            50.384615
# Precision                  0.570030
# Recall                     0.913803
# F-Score                    0.662812
# Filtered                   1.000000
# dtype: float64

# %%
df_rl_filtered.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 59 (RL)                  1181                   40             51
# Episode 29 (RL)                   977                   45             44
# Episode 19 (RL)                   898                   38             45
# Episode 26 (RL)                   573                   62             46
# Episode 52 (RL)                  1129                   64             62
#
#                  Precision    Recall   F-Score Filtered
# Episode 59 (RL)   0.909091  0.909091  0.909091        1
# Episode 29 (RL)   0.871795  0.944444  0.906667        1
# Episode 19 (RL)   0.909091  0.857143  0.882353        1
# Episode 26 (RL)   0.764706  0.975000  0.857143        1
# Episode 52 (RL)   0.823529  0.875000  0.848485        1

# %%
df_rl_lead3.mean()
# Out:
# Reference data length     52.876712
# Filtered data length      42.123288
# Summary length           112.054795
# Precision                  0.420480
# Recall                     0.219908
# F-Score                    0.282445
# Filtered                   0.356164
# dtype: float64

# %%
df_rl_lead3.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 4 (RL)                     41                    0             57
# Episode 8 (RL)                     71                    0             96
# Episode 3 (RL)                     37                    0             63
# Episode 55 (RL)                    82                  178            135
# Episode 58 (RL)                    52                    0            106
#
#                  Precision    Recall   F-Score Filtered
# Episode 4 (RL)    0.948718  0.740000  0.831461        0
# Episode 8 (RL)    0.952381  0.714286  0.816327        0
# Episode 3 (RL)    0.823529  0.528302  0.643678        0
# Episode 55 (RL)   0.746032  0.489583  0.591195        1
# Episode 58 (RL)   0.878049  0.433735  0.580645        0

# %%
if not df_ref.empty:
    print(df_rl_ref.mean())

# %% [markdown]
# ***

# %% [markdown]
# # **CNN/Dailymail Dataset**

# %%
df_orig_cnndm, df_ref_cnndm, df_filtered_cnndm, df_leadn_cnndm = calculate_rouge_qubart(data=cnndm_lines, len_data=len(cnndm_lines), similarity_threshold=0.2, use_columns=True)
df_cnndm_r1, df_cnndm_r2, df_cnndm_rl = get_rouge_columns(df_orig_cnndm)
df_cnndm_r1_filtered, df_cnndm_r2_filtered, df_cnndm_rl_filtered = get_rouge_columns(df_filtered_cnndm)
df_cnndm_r1_lead3, df_cnndm_r2_lead3, df_cnndm_rl_lead3 = get_rouge_columns(df_leadn_cnndm)
if not df_ref_cnndm.empty:
    df_cnndm_r1_ref, df_cnndm_r2_ref, df_cnndm_rl_ref = get_rouge_columns(df_ref_cnndm)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10

# %% [markdown]
# ## **R1 metric**

# %%
df_cnndm_r1.mean()
# Out:
# Reference data length    667.410000
# Filtered data length     601.490000
# Summary length            58.480000
# Precision                  0.166813
# Recall                     0.908705
# F-Score                    0.276730
# Filtered                   0.980000
# dtype: float64

# %%
df_cnndm_r1.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#               Reference data length Filtered data length Summary length  \
# Entry 65 (R1)                   150                  150             57
# Entry 20 (R1)                   201                  201             53
# Entry 22 (R1)                   270                  270             49
# Entry 5 (R1)                    245                  245             54
# Entry 48 (R1)                   403                    0             90
#
#                Precision    Recall   F-Score Filtered
# Entry 65 (R1)   0.386792  0.891304  0.539474        1
# Entry 20 (R1)   0.350000  0.933333  0.509091        1
# Entry 22 (R1)   0.310078  0.975610  0.470588        1
# Entry 5 (R1)    0.320000  0.869565  0.467836        1
# Entry 48 (R1)   0.310345  0.913043  0.463235        0

# %%
df_cnndm_r1_filtered.mean()
# Out:
# Reference data length    668.632653
# Filtered data length     613.765306
# Summary length            58.183673
# Precision                  0.177446
# Recall                     0.908345
# F-Score                    0.290987
# Filtered                   1.000000
# dtype: float64

# %%
df_cnndm_r1_filtered.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#               Reference data length Filtered data length Summary length  \
# Entry 21 (R1)                   228                   80             43
# Entry 65 (R1)                   150                  150             57
# Entry 20 (R1)                   201                  201             53
# Entry 22 (R1)                   270                  270             49
# Entry 5 (R1)                    245                  245             54
#
#                Precision    Recall   F-Score Filtered
# Entry 21 (R1)   0.469697  0.837838  0.601942        1
# Entry 65 (R1)   0.386792  0.891304  0.539474        1
# Entry 20 (R1)   0.350000  0.933333  0.509091        1
# Entry 22 (R1)   0.310078  0.975610  0.470588        1
# Entry 5 (R1)    0.320000  0.869565  0.467836        1

# %%
df_cnndm_r1_lead3.mean()
# Out:
# Reference data length     53.810000
# Filtered data length     601.490000
# Summary length           514.970000
# Precision                  0.828009
# Recall                     0.174894
# F-Score                    0.281301
# Filtered                   0.980000
# dtype: float64

# %%
df_cnndm_r1_lead3.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#               Reference data length Filtered data length Summary length  \
# Entry 32 (R1)                    80                  377            377
# Entry 42 (R1)                    79                  546            188
# Entry 56 (R1)                    63                  351            351
# Entry 78 (R1)                    77                  498            290
# Entry 47 (R1)                    67                  447             88
#
#                Precision    Recall   F-Score Filtered
# Entry 32 (R1)   0.985507  0.356021  0.523077        1
# Entry 42 (R1)   0.723077  0.373016  0.492147        1
# Entry 56 (R1)   0.910714  0.326923  0.481132        1
# Entry 78 (R1)   0.768116  0.339744  0.471111        1
# Entry 47 (R1)   0.549020  0.394366  0.459016        1

# %%
if not df_ref_cnndm.empty:
    print(df_cnndm_r1_ref.mean())
# Out:
# Reference data length     66.168317
# Filtered data length     607.910891
# Summary length           510.247525
# Precision                  0.823022
# Recall                     0.175404
# F-Score                    0.281157
# Filtered                   0.980198
# dtype: float64

# %%
df_cnndm_r1_ref.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#               Reference data length Filtered data length Summary length  \
# Entry 32 (R1)                    80                  377            377
# Entry 42 (R1)                    79                  546            188
# Entry 56 (R1)                    63                  351            351
# Entry 78 (R1)                    77                  498            290
# Entry 47 (R1)                    67                  447             88
#
#                Precision    Recall   F-Score Filtered
# Entry 32 (R1)   0.985507  0.356021  0.523077        1
# Entry 42 (R1)   0.723077  0.373016  0.492147        1
# Entry 56 (R1)   0.910714  0.326923  0.481132        1
# Entry 78 (R1)   0.768116  0.339744  0.471111        1
# Entry 47 (R1)   0.549020  0.394366  0.459016        1

# %% [markdown]
# ## **R2 metric**

# %%
df_cnndm_r2.mean()
# Out:
# Reference data length    667.410000
# Filtered data length     601.490000
# Summary length            58.480000
# Precision                  0.093359
# Recall                     0.797589
# F-Score                    0.163495
# Filtered                   0.980000
# dtype: float64

# %%
df_cnndm_r2.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 65 (R2)                   150                  150             57
# Episode 20 (R2)                   201                  201             53
# Episode 56 (R2)                   351                  351             62
# Episode 48 (R2)                   403                    0             90
# Episode 22 (R2)                   270                  270             49
#
#                  Precision    Recall   F-Score Filtered
# Episode 65 (R2)   0.273333  0.732143  0.398058        1
# Episode 20 (R2)   0.244565  0.865385  0.381356        1
# Episode 56 (R2)   0.220833  0.868852  0.352159        1
# Episode 48 (R2)   0.216901  0.855556  0.346067        0
# Episode 22 (R2)   0.191388  0.851064  0.312500        1

# %%
df_cnndm_r2_filtered.mean()
# Out:
# Reference data length    668.632653
# Filtered data length     613.765306
# Summary length            58.183673
# Precision                  0.101610
# Recall                     0.796625
# F-Score                    0.175592
# Filtered                   1.000000
# dtype: float64

# %%
df_cnndm_r2_filtered.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 21 (R2)                   228                   80             43
# Episode 65 (R2)                   150                  150             57
# Episode 20 (R2)                   201                  201             53
# Episode 56 (R2)                   351                  351             62
# Episode 18 (R2)                   641                  409             85
#
#                  Precision    Recall   F-Score Filtered
# Episode 21 (R2)   0.397590  0.785714  0.528000        1
# Episode 65 (R2)   0.273333  0.732143  0.398058        1
# Episode 20 (R2)   0.244565  0.865385  0.381356        1
# Episode 56 (R2)   0.220833  0.868852  0.352159        1
# Episode 18 (R2)   0.201102  0.879518  0.327354        1

# %%
df_cnndm_r2_lead3.mean()
# Out:
# Reference data length     53.810000
# Filtered data length     601.490000
# Summary length           514.970000
# Precision                  0.471494
# Recall                     0.067722
# F-Score                    0.115089
# Filtered                   0.980000
# dtype: float64

# %%
df_cnndm_r2_lead3.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 32 (R2)                    80                  377            377
# Episode 56 (R2)                    63                  351            351
# Episode 73 (R2)                    79                  598            428
# Episode 82 (R2)                    82                  702            460
# Episode 16 (R2)                    54                  691            247
#
#                  Precision    Recall   F-Score Filtered
# Episode 32 (R2)   0.914634  0.241158  0.381679        1
# Episode 56 (R2)   0.822581  0.212500  0.337748        1
# Episode 73 (R2)   0.904762  0.180952  0.301587        1
# Episode 82 (R2)   0.768293  0.157500  0.261411        1
# Episode 16 (R2)   0.673077  0.156951  0.254545        1

# %%
if not df_ref_cnndm.empty:
    print(df_cnndm_r2_ref.mean())
# Out:
# Reference data length     66.168317
# Filtered data length     607.910891
# Summary length           510.247525
# Precision                  0.467309
# Recall                     0.067393
# F-Score                    0.114349
# Filtered                   0.980198
# dtype: float64

# %%
df_cnndm_r2_ref.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 32 (R2)                    80                  377            377
# Episode 56 (R2)                    63                  351            351
# Episode 73 (R2)                    79                  598            428
# Episode 82 (R2)                    82                  702            460
# Episode 16 (R2)                    54                  691            247
#
#                  Precision    Recall   F-Score Filtered
# Episode 32 (R2)   0.914634  0.241158  0.381679        1
# Episode 56 (R2)   0.822581  0.212500  0.337748        1
# Episode 73 (R2)   0.904762  0.180952  0.301587        1
# Episode 82 (R2)   0.768293  0.157500  0.261411        1
# Episode 16 (R2)   0.673077  0.156951  0.254545        1

# %% [markdown]
# ## **RL metric**

# %%
df_cnndm_rl.mean()
# Out:
# Reference data length    667.410000
# Filtered data length     601.490000
# Summary length            58.480000
# Precision                  0.165580
# Recall                     0.901866
# F-Score                    0.274668
# Filtered                   0.980000
# dtype: float64

# %%
df_cnndm_rl.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 65 (RL)                   150                  150             57
# Episode 20 (RL)                   201                  201             53
# Episode 22 (RL)                   270                  270             49
# Episode 48 (RL)                   403                    0             90
# Episode 5 (RL)                    245                  245             54
#
#                  Precision    Recall   F-Score Filtered
# Episode 65 (RL)   0.386792  0.891304  0.539474        1
# Episode 20 (RL)   0.350000  0.933333  0.509091        1
# Episode 22 (RL)   0.310078  0.975610  0.470588        1
# Episode 48 (RL)   0.310345  0.913043  0.463235        0
# Episode 5 (RL)    0.312000  0.847826  0.456140        1

# %%
df_cnndm_rl_filtered.mean()
# Out:
# Reference data length    668.632653
# Filtered data length     613.765306
# Summary length            58.183673
# Precision                  0.176069
# Recall                     0.901523
# F-Score                    0.288723
# Filtered                   1.000000
# dtype: float64

# %%
df_cnndm_rl_filtered.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 21 (RL)                   228                   80             43
# Episode 65 (RL)                   150                  150             57
# Episode 20 (RL)                   201                  201             53
# Episode 22 (RL)                   270                  270             49
# Episode 5 (RL)                    245                  245             54
#
#                  Precision    Recall   F-Score Filtered
# Episode 21 (RL)   0.469697  0.837838  0.601942        1
# Episode 65 (RL)   0.386792  0.891304  0.539474        1
# Episode 20 (RL)   0.350000  0.933333  0.509091        1
# Episode 22 (RL)   0.310078  0.975610  0.470588        1
# Episode 5 (RL)    0.312000  0.847826  0.456140        1

# %%
df_cnndm_rl_lead3.mean()
# Out:
# Reference data length     53.810000
# Filtered data length     601.490000
# Summary length           514.970000
# Precision                  0.784707
# Recall                     0.164819
# F-Score                    0.265509
# Filtered                   0.980000
# dtype: float64

# %%
df_cnndm_rl_lead3.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 32 (RL)                    80                  377            377
# Episode 56 (RL)                    63                  351            351
# Episode 42 (RL)                    79                  546            188
# Episode 78 (RL)                    77                  498            290
# Episode 82 (RL)                    82                  702            460
#
#                  Precision    Recall   F-Score Filtered
# Episode 32 (RL)   0.985507  0.356021  0.523077        1
# Episode 56 (RL)   0.910714  0.326923  0.481132        1
# Episode 42 (RL)   0.692308  0.357143  0.471204        1
# Episode 78 (RL)   0.739130  0.326923  0.453333        1
# Episode 82 (RL)   0.970149  0.286344  0.442177        1

# %%
if not df_ref_cnndm.empty:
    print(df_cnndm_rl_ref.mean())
# Out:
# Reference data length     66.168317
# Filtered data length     607.910891
# Summary length           510.247525
# Precision                  0.779346
# Recall                     0.164869
# F-Score                    0.264860
# Filtered                   0.980198
# dtype: float64

# %%
df_cnndm_rl_ref.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 32 (RL)                    80                  377            377
# Episode 56 (RL)                    63                  351            351
# Episode 42 (RL)                    79                  546            188
# Episode 78 (RL)                    77                  498            290
# Episode 82 (RL)                    82                  702            460
#
#                  Precision    Recall   F-Score Filtered
# Episode 32 (RL)   0.985507  0.356021  0.523077        1
# Episode 56 (RL)   0.910714  0.326923  0.481132        1
# Episode 42 (RL)   0.692308  0.357143  0.471204        1
# Episode 78 (RL)   0.739130  0.326923  0.453333        1
# Episode 82 (RL)   0.970149  0.286344  0.442177        1

# %% [markdown]
# ***

# %% [markdown]
# # **Wikihow**

# %%
df_orig_wikihow, df_ref_wikihow, df_filtered_wikihow, df_leadn_wikihow = calculate_rouge_qubart(data=wikihow_lines, len_data=len(wikihow_lines), similarity_threshold=0.2, use_columns=True)
df_wikihow_r1, df_wikihow_r2, df_wikihow_rl = get_rouge_columns(df_orig_wikihow)
df_wikihow_r1_filtered, df_wikihow_r2_filtered, df_wikihow_rl_filtered = get_rouge_columns(df_filtered_wikihow)
df_wikihow_r1_lead3, df_wikihow_r2_lead3, df_wikihow_rl_lead3 = get_rouge_columns(df_leadn_wikihow)
if not df_ref_wikihow.empty:
    df_wikihow_r1_ref, df_wikihow_r2_ref, df_wikihow_rl_ref = get_rouge_columns(df_ref_wikihow)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10

# %% [markdown]
# ## **R1 metric**

# %%
df_wikihow_r1.mean()
# Out:
# Reference data length    600.980000
# Filtered data length     550.780000
# Summary length            54.490000
# Precision                  0.204248
# Recall                     0.875236
# F-Score                    0.316176
# Filtered                   0.950000
# dtype: float64

# %%
df_wikihow_r1.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#               Reference data length Filtered data length Summary length  \
# Entry 12 (R1)                    66                   66             66
# Entry 67 (R1)                    80                   80             52
# Entry 10 (R1)                   138                  138             60
# Entry 85 (R1)                   174                  174             61
# Entry 23 (R1)                   165                    0             55
#
#                Precision    Recall   F-Score Filtered
# Entry 12 (R1)   0.909091  0.925926  0.917431        1
# Entry 67 (R1)   0.633333  0.950000  0.760000        1
# Entry 10 (R1)   0.470588  0.930233  0.625000        1
# Entry 85 (R1)   0.464646  0.938776  0.621622        1
# Entry 23 (R1)   0.444444  0.930233  0.601504        0

# %%
df_wikihow_r1_filtered.mean()
# Out:
# Reference data length    610.263158
# Filtered data length     579.768421
# Summary length            54.178947
# Precision                  0.218269
# Recall                     0.872658
# F-Score                    0.321427
# Filtered                   1.000000
# dtype: float64

# %%
df_wikihow_r1_filtered.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#               Reference data length Filtered data length Summary length  \
# Entry 12 (R1)                    66                   66             66
# Entry 67 (R1)                    80                   80             52
# Entry 10 (R1)                   138                  138             60
# Entry 85 (R1)                   174                  174             61
# Entry 56 (R1)                   156                  156             53
#
#                Precision    Recall   F-Score Filtered
# Entry 12 (R1)   0.909091  0.925926  0.917431        1
# Entry 67 (R1)   0.633333  0.950000  0.760000        1
# Entry 10 (R1)   0.470588  0.930233  0.625000        1
# Entry 85 (R1)   0.464646  0.938776  0.621622        1
# Entry 56 (R1)   0.446809  0.913043  0.600000        1

# %%
df_wikihow_r1_lead3.mean()
# Out:
# Reference data length     58.230000
# Filtered data length     550.780000
# Summary length           479.590000
# Precision                  0.670821
# Recall                     0.135838
# F-Score                    0.211540
# Filtered                   0.950000
# dtype: float64

# %%
df_wikihow_r1_lead3.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#               Reference data length Filtered data length Summary length  \
# Entry 92 (R1)                   159                  609            127
# Entry 48 (R1)                    88                  273            273
# Entry 26 (R1)                    64                  266            266
# Entry 19 (R1)                   137                    0            348
# Entry 10 (R1)                    82                  138            138
#
#                Precision    Recall   F-Score Filtered
# Entry 92 (R1)   0.433735  0.428571  0.431138        1
# Entry 48 (R1)   0.787234  0.286822  0.420455        1
# Entry 26 (R1)   0.804878  0.270492  0.404908        1
# Entry 19 (R1)   0.556962  0.275000  0.368201        1
# Entry 10 (R1)   0.421875  0.317647  0.362416        1

# %%
if not df_ref_wikihow.empty:
    print(df_wikihow_r1_ref.mean())
# Out:
# Reference data length     61.306931
# Filtered data length     548.980198
# Summary length           475.069307
# Precision                  0.670544
# Recall                     0.136175
# F-Score                    0.212106
# Filtered                   0.950495
# dtype: float64

# %%
df_wikihow_r1_ref.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#               Reference data length Filtered data length Summary length  \
# Entry 92 (R1)                   159                  609            127
# Entry 48 (R1)                    88                  273            273
# Entry 26 (R1)                    64                  266            266
# Entry 19 (R1)                   137                    0            348
# Entry 10 (R1)                    82                  138            138
#
#                Precision    Recall   F-Score Filtered
# Entry 92 (R1)   0.433735  0.428571  0.431138        1
# Entry 48 (R1)   0.787234  0.286822  0.420455        1
# Entry 26 (R1)   0.804878  0.270492  0.404908        1
# Entry 19 (R1)   0.556962  0.275000  0.368201        1
# Entry 10 (R1)   0.421875  0.317647  0.362416        1

# %% [markdown]
# ## **R2 metric**

# %%
df_wikihow_r2.mean()
# Out:
# Reference data length    600.980000
# Filtered data length     550.780000
# Summary length            54.490000
# Precision                  0.121984
# Recall                     0.777090
# F-Score                    0.197043
# Filtered                   0.950000
# dtype: float64

# %%
df_wikihow_r2.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 12 (R2)                    66                   66             66
# Episode 67 (R2)                    80                   80             52
# Episode 10 (R2)                   138                  138             60
# Episode 23 (R2)                   165                    0             55
# Episode 85 (R2)                   174                  174             61
#
#                  Precision    Recall   F-Score Filtered
# Episode 12 (R2)   0.850746  0.876923  0.863636        1
# Episode 67 (R2)   0.551724  0.888889  0.680851        1
# Episode 10 (R2)   0.388060  0.896552  0.541667        1
# Episode 23 (R2)   0.345324  0.888889  0.497409        0
# Episode 85 (R2)   0.316129  0.830508  0.457944        1

# %%
df_wikihow_r2_filtered.mean()
# Out:
# Reference data length    610.263158
# Filtered data length     579.768421
# Summary length            54.178947
# Precision                  0.123994
# Recall                     0.774288
# F-Score                    0.199824
# Filtered                   1.000000
# dtype: float64

# %%
df_wikihow_r2_filtered.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 12 (R2)                    66                   66             66
# Episode 67 (R2)                    80                   80             52
# Episode 10 (R2)                   138                  138             60
# Episode 85 (R2)                   174                  174             61
# Episode 8 (R2)                    179                  179             68
#
#                  Precision    Recall   F-Score Filtered
# Episode 12 (R2)   0.850746  0.876923  0.863636        1
# Episode 67 (R2)   0.551724  0.888889  0.680851        1
# Episode 10 (R2)   0.388060  0.896552  0.541667        1
# Episode 85 (R2)   0.316129  0.830508  0.457944        1
# Episode 8 (R2)    0.306818  0.830769  0.448133        1

# %%
df_wikihow_r2_lead3.mean()
# Out:
# Reference data length     58.230000
# Filtered data length     550.780000
# Summary length           479.590000
# Precision                  0.249316
# Recall                     0.032478
# F-Score                    0.053102
# Filtered                   0.950000
# dtype: float64

# %%
df_wikihow_r2_lead3.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 26 (R2)                    64                  266            266
# Episode 48 (R2)                    88                  273            273
# Episode 92 (R2)                   159                  609            127
# Episode 2 (R2)                    140                  261            261
# Episode 10 (R2)                    82                  138            138
#
#                  Precision    Recall   F-Score Filtered
# Episode 26 (R2)   0.483333  0.124464  0.197952        1
# Episode 48 (R2)   0.356164  0.109705  0.167742        1
# Episode 92 (R2)   0.147059  0.157480  0.152091        1
# Episode 2 (R2)    0.150000  0.078947  0.103448        1
# Episode 10 (R2)   0.134146  0.082090  0.101852        1

# %%
if not df_ref_wikihow.empty:
    print(df_wikihow_r2_ref.mean())
# Out:
# Reference data length     61.306931
# Filtered data length     548.980198
# Summary length           475.069307
# Precision                  0.249760
# Recall                     0.032995
# F-Score                    0.053879
# Filtered                   0.950495
# dtype: float64

# %%
df_wikihow_r2_ref.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 26 (R2)                    64                  266            266
# Episode 48 (R2)                    88                  273            273
# Episode 92 (R2)                   159                  609            127
# Episode 99 (R2)                   369                  369             23
# Episode 2 (R2)                    140                  261            261
#
#                  Precision    Recall   F-Score Filtered
# Episode 26 (R2)   0.483333  0.124464  0.197952        1
# Episode 48 (R2)   0.356164  0.109705  0.167742        1
# Episode 92 (R2)   0.147059  0.157480  0.152091        1
# Episode 99 (R2)   0.294118  0.084746  0.131579        1
# Episode 2 (R2)    0.150000  0.078947  0.103448        1

# %% [markdown]
# ## **RL metric**

# %%
df_wikihow_rl.mean()
# Out:
# Reference data length    600.980000
# Filtered data length     550.780000
# Summary length            54.490000
# Precision                  0.203947
# Recall                     0.874032
# F-Score                    0.315720
# Filtered                   0.950000
# dtype: float64

# %%
df_wikihow_rl.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 12 (RL)                    66                   66             66
# Episode 67 (RL)                    80                   80             52
# Episode 10 (RL)                   138                  138             60
# Episode 85 (RL)                   174                  174             61
# Episode 23 (RL)                   165                    0             55
#
#                  Precision    Recall   F-Score Filtered
# Episode 12 (RL)   0.909091  0.925926  0.917431        1
# Episode 67 (RL)   0.633333  0.950000  0.760000        1
# Episode 10 (RL)   0.470588  0.930233  0.625000        1
# Episode 85 (RL)   0.464646  0.938776  0.621622        1
# Episode 23 (RL)   0.444444  0.930233  0.601504        0

# %%
df_wikihow_rl_filtered.mean()
# Out:
# Reference data length    610.263158
# Filtered data length     579.768421
# Summary length            54.178947
# Precision                  0.217953
# Recall                     0.871392
# F-Score                    0.320947
# Filtered                   1.000000
# dtype: float64

# %%
df_wikihow_rl_filtered.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 12 (RL)                    66                   66             66
# Episode 67 (RL)                    80                   80             52
# Episode 10 (RL)                   138                  138             60
# Episode 85 (RL)                   174                  174             61
# Episode 56 (RL)                   156                  156             53
#
#                  Precision    Recall   F-Score Filtered
# Episode 12 (RL)   0.909091  0.925926  0.917431        1
# Episode 67 (RL)   0.633333  0.950000  0.760000        1
# Episode 10 (RL)   0.470588  0.930233  0.625000        1
# Episode 85 (RL)   0.464646  0.938776  0.621622        1
# Episode 56 (RL)   0.446809  0.913043  0.600000        1

# %%
df_wikihow_rl_lead3.mean()
# Out:
# Reference data length     58.230000
# Filtered data length     550.780000
# Summary length           479.590000
# Precision                  0.638360
# Recall                     0.128151
# F-Score                    0.200181
# Filtered                   0.950000
# dtype: float64

# %%
df_wikihow_rl_lead3.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 48 (RL)                    88                  273            273
# Episode 26 (RL)                    64                  266            266
# Episode 92 (RL)                   159                  609            127
# Episode 19 (RL)                   137                    0            348
# Episode 10 (RL)                    82                  138            138
#
#                  Precision    Recall   F-Score Filtered
# Episode 48 (RL)   0.787234  0.286822  0.420455        1
# Episode 26 (RL)   0.804878  0.270492  0.404908        1
# Episode 92 (RL)   0.397590  0.392857  0.395210        1
# Episode 19 (RL)   0.518987  0.256250  0.343096        1
# Episode 10 (RL)   0.390625  0.294118  0.335570        1

# %%
if not df_ref_wikihow.empty:  
    print(df_wikihow_rl_ref.mean())
# Out:
# Reference data length     61.306931
# Filtered data length     548.980198
# Summary length           475.069307
# Precision                  0.637697
# Recall                     0.128376
# F-Score                    0.200564
# Filtered                   0.950495
# dtype: float64

# %%
df_wikihow_rl_ref.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 48 (RL)                    88                  273            273
# Episode 26 (RL)                    64                  266            266
# Episode 92 (RL)                   159                  609            127
# Episode 19 (RL)                   137                    0            348
# Episode 10 (RL)                    82                  138            138
#
#                  Precision    Recall   F-Score Filtered
# Episode 48 (RL)   0.787234  0.286822  0.420455        1
# Episode 26 (RL)   0.804878  0.270492  0.404908        1
# Episode 92 (RL)   0.397590  0.392857  0.395210        1
# Episode 19 (RL)   0.518987  0.256250  0.343096        1
# Episode 10 (RL)   0.390625  0.294118  0.335570        1

# %% [markdown]
# ***

# %% [markdown]
# # **XSum**

# %%
df_orig_xsum, df_ref_xsum, df_filtered_xsum, df_leadn_xsum = calculate_rouge_qubart(data=xsum_lines, len_data=len(xsum_lines), similarity_threshold=0.2, use_columns=True)
df_xsum_r1, df_xsum_r2, df_xsum_rl = get_rouge_columns(df_orig_xsum)
df_xsum_r1_filtered, df_xsum_r2_filtered, df_xsum_rl_filtered = get_rouge_columns(df_filtered_xsum)
df_xsum_r1_lead3, df_xsum_r2_lead3, df_xsum_rl_lead3 = get_rouge_columns(df_leadn_xsum)
if not df_ref_xsum.empty:
    df_xsum_r1_ref, df_xsum_r2_ref, df_xsum_rl_ref = get_rouge_columns(df_ref_xsum)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10

# %% [markdown]
# ## **R1 metric**

# %%
df_xsum_r1.mean()
# Out:
# Reference data length    405.980000
# Filtered data length     342.100000
# Summary length            50.990000
# Precision                  0.249228
# Recall                     0.883862
# F-Score                    0.363612
# Filtered                   0.910000
# dtype: float64

# %%
df_xsum_r1.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#               Reference data length Filtered data length Summary length  \
# Entry 38 (R1)                    63                   63             61
# Entry 47 (R1)                    56                    0             58
# Entry 24 (R1)                    59                    0             53
# Entry 0 (R1)                     51                   51             53
# Entry 84 (R1)                    88                   88             52
#
#                Precision    Recall   F-Score Filtered
# Entry 38 (R1)   0.938776  0.901961  0.920000        1
# Entry 47 (R1)   0.934783  0.860000  0.895833        0
# Entry 24 (R1)   0.840000  0.954545  0.893617        0
# Entry 0 (R1)    0.723404  0.790698  0.755556        1
# Entry 84 (R1)   0.634921  0.930233  0.754717        1

# %%
df_xsum_r1_filtered.mean()
# Out:
# Reference data length    407.340659
# Filtered data length     375.934066
# Summary length            51.142857
# Precision                  0.269266
# Recall                     0.880395
# F-Score                    0.376324
# Filtered                   1.000000
# dtype: float64

# %%
df_xsum_r1_filtered.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#               Reference data length Filtered data length Summary length  \
# Entry 38 (R1)                    63                   63             61
# Entry 32 (R1)                   268                   20             56
# Entry 0 (R1)                     51                   51             53
# Entry 84 (R1)                    88                   88             52
# Entry 11 (R1)                    84                   84             53
#
#                Precision    Recall   F-Score Filtered
# Entry 38 (R1)   0.938776  0.901961  0.920000        1
# Entry 32 (R1)   0.913043  0.656250  0.763636        1
# Entry 0 (R1)    0.723404  0.790698  0.755556        1
# Entry 84 (R1)   0.634921  0.930233  0.754717        1
# Entry 11 (R1)   0.597403  0.938776  0.730159        1

# %%
df_xsum_r1_lead3.mean()
# Out:
# Reference data length     22.380000
# Filtered data length     342.100000
# Summary length           349.400000
# Precision                  0.620619
# Recall                     0.082302
# F-Score                    0.141569
# Filtered                   0.910000
# dtype: float64

# %%
df_xsum_r1_lead3.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#               Reference data length Filtered data length Summary length  \
# Entry 84 (R1)                    20                   88             88
# Entry 38 (R1)                    13                   63             63
# Entry 53 (R1)                    26                  109            109
# Entry 39 (R1)                    21                   93             93
# Entry 45 (R1)                    27                  139            139
#
#                Precision    Recall   F-Score Filtered
# Entry 84 (R1)   0.631579  0.190476  0.292683        1
# Entry 38 (R1)   0.615385  0.163265  0.258065        1
# Entry 53 (R1)   0.565217  0.158537  0.247619        1
# Entry 39 (R1)   0.523810  0.159420  0.244444        1
# Entry 45 (R1)   0.576923  0.148515  0.236220        1

# %%
if not df_ref_xsum.empty:
    print(df_xsum_r1_ref.mean())
# Out:
# Reference data length     30.227723
# Filtered data length     346.376238
# Summary length           346.188119
# Precision                  0.615941
# Recall                     0.082619
# F-Score                    0.141445
# Filtered                   0.910891
# dtype: float64

# %%
df_xsum_r1_ref.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#               Reference data length Filtered data length Summary length  \
# Entry 84 (R1)                    20                   88             88
# Entry 38 (R1)                    13                   63             63
# Entry 53 (R1)                    26                  109            109
# Entry 39 (R1)                    21                   93             93
# Entry 45 (R1)                    27                  139            139
#
#                Precision    Recall   F-Score Filtered
# Entry 84 (R1)   0.631579  0.190476  0.292683        1
# Entry 38 (R1)   0.615385  0.163265  0.258065        1
# Entry 53 (R1)   0.565217  0.158537  0.247619        1
# Entry 39 (R1)   0.523810  0.159420  0.244444        1
# Entry 45 (R1)   0.576923  0.148515  0.236220        1

# %% [markdown]
# ## **R2 metric**

# %%
df_xsum_r2.mean()
# Out:
# Reference data length    405.980000
# Filtered data length     342.100000
# Summary length            50.990000
# Precision                  0.162368
# Recall                     0.762958
# F-Score                    0.242643
# Filtered                   0.910000
# dtype: float64

# %%
df_xsum_r2.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 38 (R2)                    63                   63             61
# Episode 47 (R2)                    56                    0             58
# Episode 24 (R2)                    59                    0             53
# Episode 11 (R2)                    84                   84             53
# Episode 84 (R2)                    88                   88             52
#
#                  Precision    Recall   F-Score Filtered
# Episode 38 (R2)   0.809524  0.836066  0.822581        1
# Episode 47 (R2)   0.818182  0.789474  0.803571        0
# Episode 24 (R2)   0.693548  0.826923  0.754386        0
# Episode 11 (R2)   0.516484  0.870370  0.648276        1
# Episode 84 (R2)   0.505882  0.860000  0.637037        1

# %%
df_xsum_r2_filtered.mean()
# Out:
# Reference data length    407.340659
# Filtered data length     375.934066
# Summary length            51.142857
# Precision                  0.169658
# Recall                     0.759728
# F-Score                    0.251296
# Filtered                   1.000000
# dtype: float64

# %%
df_xsum_r2_filtered.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 38 (R2)                    63                   63             61
# Episode 11 (R2)                    84                   84             53
# Episode 84 (R2)                    88                   88             52
# Episode 76 (R2)                   189                   85             49
# Episode 0 (R2)                     51                   51             53
#
#                  Precision    Recall   F-Score Filtered
# Episode 38 (R2)   0.809524  0.836066  0.822581        1
# Episode 11 (R2)   0.516484  0.870370  0.648276        1
# Episode 84 (R2)   0.505882  0.860000  0.637037        1
# Episode 76 (R2)   0.460674  0.854167  0.598540        1
# Episode 0 (R2)    0.584906  0.607843  0.596154        1

# %%
df_xsum_r2_lead3.mean()
# Out:
# Reference data length     22.380000
# Filtered data length     342.100000
# Summary length           349.400000
# Precision                  0.160156
# Recall                     0.012272
# F-Score                    0.022228
# Filtered                   0.910000
# dtype: float64

# %%
df_xsum_r2_lead3.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 39 (R2)                    21                   93             93
# Episode 45 (R2)                    27                  139            139
# Episode 26 (R2)                    21                  144            144
# Episode 15 (R2)                    22                  103            188
# Episode 50 (R2)                    20                  217            261
#
#                  Precision    Recall   F-Score Filtered
# Episode 39 (R2)   0.190476  0.042553  0.069565        1
# Episode 45 (R2)   0.214286  0.041379  0.069364        1
# Episode 26 (R2)   0.250000  0.034965  0.061350        1
# Episode 15 (R2)   0.272727  0.031915  0.057143        1
# Episode 50 (R2)   0.350000  0.027559  0.051095        1

# %%
if not df_ref_xsum.empty:
    print(df_xsum_r2_ref.mean())
# Out:
# Reference data length     30.227723
# Filtered data length     346.376238
# Summary length           346.188119
# Precision                  0.158570
# Recall                     0.012151
# F-Score                    0.022008
# Filtered                   0.910891
# dtype: float64

# %%
df_xsum_r2_ref.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 39 (R2)                    21                   93             93
# Episode 45 (R2)                    27                  139            139
# Episode 26 (R2)                    21                  144            144
# Episode 15 (R2)                    22                  103            188
# Episode 50 (R2)                    20                  217            261
#
#                  Precision    Recall   F-Score Filtered
# Episode 39 (R2)   0.190476  0.042553  0.069565        1
# Episode 45 (R2)   0.214286  0.041379  0.069364        1
# Episode 26 (R2)   0.250000  0.034965  0.061350        1
# Episode 15 (R2)   0.272727  0.031915  0.057143        1
# Episode 50 (R2)   0.350000  0.027559  0.051095        1

# %% [markdown]
# ## **RL metric**

# %%
df_xsum_rl.mean()
# Out:
# Reference data length    405.980000
# Filtered data length     342.100000
# Summary length            50.990000
# Precision                  0.247542
# Recall                     0.879709
# F-Score                    0.361348
# Filtered                   0.910000
# dtype: float64

# %%
df_xsum_rl.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 38 (RL)                    63                   63             61
# Episode 47 (RL)                    56                    0             58
# Episode 24 (RL)                    59                    0             53
# Episode 84 (RL)                    88                   88             52
# Episode 11 (RL)                    84                   84             53
#
#                  Precision    Recall   F-Score Filtered
# Episode 38 (RL)   0.938776  0.901961  0.920000        1
# Episode 47 (RL)   0.934783  0.860000  0.895833        0
# Episode 24 (RL)   0.840000  0.954545  0.893617        0
# Episode 84 (RL)   0.634921  0.930233  0.754717        1
# Episode 11 (RL)   0.597403  0.938776  0.730159        1

# %%
df_xsum_rl_filtered.mean()
# Out:
# Reference data length    407.340659
# Filtered data length     375.934066
# Summary length            51.142857
# Precision                  0.267563
# Recall                     0.876643
# F-Score                    0.374091
# Filtered                   1.000000
# dtype: float64

# %%
df_xsum_rl_filtered.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 38 (RL)                    63                   63             61
# Episode 32 (RL)                   268                   20             56
# Episode 84 (RL)                    88                   88             52
# Episode 11 (RL)                    84                   84             53
# Episode 0 (RL)                     51                   51             53
#
#                  Precision    Recall   F-Score Filtered
# Episode 38 (RL)   0.938776  0.901961  0.920000        1
# Episode 32 (RL)   0.913043  0.656250  0.763636        1
# Episode 84 (RL)   0.634921  0.930233  0.754717        1
# Episode 11 (RL)   0.597403  0.938776  0.730159        1
# Episode 0 (RL)    0.680851  0.744186  0.711111        1

# %%
df_xsum_rl_lead3.mean()
# Out:
# Reference data length     22.380000
# Filtered data length     342.100000
# Summary length           349.400000
# Precision                  0.540540
# Recall                     0.070307
# F-Score                    0.121312
# Filtered                   0.910000
# dtype: float64

# %%
df_xsum_rl_lead3.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 84 (RL)                    20                   88             88
# Episode 83 (RL)                    31                  409            409
# Episode 39 (RL)                    21                   93             93
# Episode 64 (RL)                    21                  708            221
# Episode 61 (RL)                    30                  258            298
#
#                  Precision    Recall   F-Score Filtered
# Episode 84 (RL)   0.526316  0.158730  0.243902        1
# Episode 83 (RL)   0.750000  0.117647  0.203390        1
# Episode 39 (RL)   0.428571  0.130435  0.200000        1
# Episode 64 (RL)   0.636364  0.114754  0.194444        1
# Episode 61 (RL)   0.678571  0.110465  0.190000        1

# %%
if not df_ref_xsum.empty:
    print(df_xsum_rl_ref.mean())
# Out:
# Reference data length     30.227723
# Filtered data length     346.376238
# Summary length           346.188119
# Precision                  0.536288
# Recall                     0.070459
# F-Score                    0.121069
# Filtered                   0.910891
# dtype: float64

# %%
df_xsum_rl_ref.sort_values(by=['F-Score'], ascending=False).head()
# Out:
#                 Reference data length Filtered data length Summary length  \
# Episode 84 (RL)                    20                   88             88
# Episode 83 (RL)                    31                  409            409
# Episode 39 (RL)                    21                   93             93
# Episode 64 (RL)                    21                  708            221
# Episode 61 (RL)                    30                  258            298
#
#                  Precision    Recall   F-Score Filtered
# Episode 84 (RL)   0.526316  0.158730  0.243902        1
# Episode 83 (RL)   0.750000  0.117647  0.203390        1
# Episode 39 (RL)   0.428571  0.130435  0.200000        1
# Episode 64 (RL)   0.636364  0.114754  0.194444        1
# Episode 61 (RL)   0.678571  0.110465  0.190000        1

# %% [markdown]
# ***
